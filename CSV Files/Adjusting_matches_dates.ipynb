# %%
import pandas as pd

# %%
matches_df = pd.read_csv('matchesTable.csv')

# %%
matches_df
# Out:
#        Season             HomeTeamName              AwayTeamName  \
# 0     2021/22        Tottenham Hotspur  Brighton and Hove Albion
# 1     2021/22                Brentford           West Ham United
# 2     2021/22           Leicester City            Crystal Palace
# 3     2021/22             Norwich City                   Burnley
# 4     2021/22          Manchester City                 Liverpool
# ...       ...                      ...                       ...
# 1445  2018/19                   Fulham            Crystal Palace
# 1446  2018/19        Huddersfield Town                   Chelsea
# 1447  2018/19                  Watford  Brighton and Hove Albion
# 1448  2018/19  Wolverhampton Wanderers                   Everton
# 1449  2018/19        Manchester United            Leicester City
#
#                  Date  HomePossession  HomeYellowCards  HomeRedCards  \
# 0     Sat 16 Apr 2022            48.5                3             0
# ...

# %%
matches_df['Date'] = pd.to_datetime(matches_df['Date']).dt.date

# %%
matches_df
# Out:
#        Season             HomeTeamName              AwayTeamName        Date  \
# 0     2021/22        Tottenham Hotspur  Brighton and Hove Albion  2022-04-16
# 1     2021/22                Brentford           West Ham United  2022-04-10
# 2     2021/22           Leicester City            Crystal Palace  2022-04-10
# 3     2021/22             Norwich City                   Burnley  2022-04-10
# 4     2021/22          Manchester City                 Liverpool  2022-04-10
# ...       ...                      ...                       ...         ...
# 1445  2018/19                   Fulham            Crystal Palace  2018-08-11
# 1446  2018/19        Huddersfield Town                   Chelsea  2018-08-11
# 1447  2018/19                  Watford  Brighton and Hove Albion  2018-08-11
# 1448  2018/19  Wolverhampton Wanderers                   Everton  2018-08-11
# 1449  2018/19        Manchester United            Leicester City  2018-08-10
#
# ...

# %%
matches_df.to_csv('matchesTableDateAdjusted.csv', index=False)
